# %%
import numpy as np
np.random.seed(10)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Unfiltered data - new

# %%
train_data = np.load('./Unfiltered/POD_Coeffs_train.npy')
test_data = np.load('./Unfiltered/POD_Coeffs_test.npy')

# %%
plt.figure()
plt.plot(train_data[0,:])
plt.plot(train_data[1,:])
plt.plot(train_data[2,:])
plt.show()

# %%
plt.figure()
plt.plot(test_data[0,:])
plt.plot(test_data[1,:])
plt.plot(test_data[2,:])
plt.show()

# %% [markdown]
# ## Filtered data (with errors in coasts, old)

# %%
train_data = np.load('./Filtered_NaN/POD_Coeffs_train.npy')
test_data = np.load('./Filtered_NaN/POD_Coeffs_test.npy')

# %%
plt.figure()
plt.plot(train_data[0,:])
plt.plot(train_data[1,:])
plt.plot(train_data[2,:])
plt.show()

# %%
plt.figure()
plt.plot(test_data[0,:])
plt.plot(test_data[1,:])
plt.plot(test_data[2,:])
plt.show()

# %% [markdown]
# ## What's the difference between the two?

# %%
train_data = np.load('./Unfiltered/POD_Coeffs_train.npy')
train_data_f = np.load('./Filtered_NaN/POD_Coeffs_train.npy')

# %%
plt.figure()
plt.plot(train_data[0]-train_data_f[0])
plt.show()

# %%
plt.figure()
plt.plot(train_data[1]-train_data_f[1])
plt.show()

# %%
plt.figure()
plt.plot(train_data[2]-train_data_f[2])
plt.show()

# %%
plt.figure()
plt.plot(train_data[3]-train_data_f[3])
plt.show()

# %%
plt.figure()
plt.plot(train_data[4]-train_data_f[4])
plt.show()

# %%
plt.figure()
plt.plot(train_data[5]-train_data_f[5])
plt.show()
